# %%
import pandas as pd
df = pd.read_csv(r'D:\datasets\MHassembly.csv')
df
# Out:
#       election_year election_type election_state constituency  \
# 0              2024      Assembly             MH    AKKALKUWA
# 1              2024      Assembly             MH    AKKALKUWA
# 2              2024      Assembly             MH    AKKALKUWA
# 3              2024      Assembly             MH    AKKALKUWA
# 4              2024      Assembly             MH    AKKALKUWA
# ...             ...           ...            ...          ...
# 4419           2024      Assembly             MH          JAT
# 4420           2024      Assembly             MH          JAT
# 4421           2024      Assembly             MH          JAT
# 4422           2024      Assembly             MH          JAT
# 4423           2024      Assembly             MH          JAT
#
#       constituency_no  serial_no                   candidate  \
# 0                   1          1          AMSHYA FULJI PADVI
# 1                   1          2              ADV K C PADAVI
# ...

# %% [markdown]
# # Data Cleaning

# %%
#duplicates
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# election_year      0
# election_type      0
# election_state     0
# constituency       0
# constituency_no    0
# serial_no          0
# candidate          0
# party              0
# evm_votes          0
# postal_votes       0
# dtype: int64

# %%
df.drop(columns = ['serial_no'], inplace = True)

# %%
df
# Out:
#       election_year election_type election_state constituency  \
# 0              2024      Assembly             MH    AKKALKUWA
# 1              2024      Assembly             MH    AKKALKUWA
# 2              2024      Assembly             MH    AKKALKUWA
# 3              2024      Assembly             MH    AKKALKUWA
# 4              2024      Assembly             MH    AKKALKUWA
# ...             ...           ...            ...          ...
# 4419           2024      Assembly             MH          JAT
# 4420           2024      Assembly             MH          JAT
# 4421           2024      Assembly             MH          JAT
# 4422           2024      Assembly             MH          JAT
# 4423           2024      Assembly             MH          JAT
#
#       constituency_no                   candidate                     party  \
# 0                   1          AMSHYA FULJI PADVI                 Shiv Sena
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4424 entries, 0 to 4423
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   election_year    4424 non-null   int64
#  1   election_type    4424 non-null   object
#  2   election_state   4424 non-null   object
#  3   constituency     4424 non-null   object
#  4   constituency_no  4424 non-null   int64
#  5   candidate        4424 non-null   object
#  6   party            4424 non-null   object
#  7   evm_votes        4424 non-null   int64
#  8   postal_votes     4424 non-null   int64
# dtypes: int64(4), object(5)
# memory usage: 311.2+ KB

# %%
df.info
# Out:
# <bound method DataFrame.info of       election_year election_type election_state constituency  \
# 0              2024      Assembly             MH    AKKALKUWA
# 1              2024      Assembly             MH    AKKALKUWA
# 2              2024      Assembly             MH    AKKALKUWA
# 3              2024      Assembly             MH    AKKALKUWA
# 4              2024      Assembly             MH    AKKALKUWA
# ...             ...           ...            ...          ...
# 4419           2024      Assembly             MH          JAT
# 4420           2024      Assembly             MH          JAT
# 4421           2024      Assembly             MH          JAT
# 4422           2024      Assembly             MH          JAT
# 4423           2024      Assembly             MH          JAT
#
#       constituency_no                   candidate                     party  \
# 0                   1          AMSHYA FULJI PADVI                 Shiv Sena
# ...

# %%
df.shape
# Out:
# (4424, 9)

# %%
df.to_csv('Accident_data')

# %%
pwd
# Out:
# 'C:\\Users\\Karan'
